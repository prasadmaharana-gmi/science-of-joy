# %%
import pandas as pd
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import defaultdict
import matplotlib
import nltk
import numpy as np
#Let me see the full string
pd.options.display.max_colwidth = 100

# %%
raw_data = pd.read_csv("C:\\Users\\g654674\\OneDrive - General Mills\\Work_OneDrive\\PGI\\Text Analytics\\Remarkability Test\\remarkability_raw_data.csv", encoding = 'latin1')

# %%
raw_data
# Out:
#      op_resp_1p_2n  \
# 0                1
# 1                2
# 2                1
# 3                2
# 4                2
# ..             ...
# 222              1
# 223              2
# 224              1
# 225              2
# 226              2
#
#                                                                                                    op_oe  \
# 0    I like the taste of the chocolate better with Pillsbury. It seems to go perfectly with the cooki...
# 1                                          The taste is better to me. The cookie seems gooey and thicker
# 2                I like the Pillsbury Chocolate Chip Cookie Dough because its sweeter, chewy and softer.
# 3                                 They have more chocolate chips and are a little thicker than Pillsbury
# 4    Nestle cookie tastes more like homemade.   Nestle also appears to contain more chocolate chips a...
# ..                                                                                                   ...
# 222                                                                    Enjoy the flavor and texture more
# 223                                             It just tasted better. It also had more chocolate chips.
# 224             It has a little bit of a better taste not as strong chocolate flavored more cookie taste
# 225  More chocolatety taste say my 10 and 7 year old kids. My husband and I like them better becaus...
# 226                                                      I think this one flattened into a cookie better
#
#      pp_resp_1p_2n  \
# 0                2
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 222              1
# 223              1
# 224              2
# 225              2
# 226              1
#
#                                                                                                    pp_oe
# 0                                I think the Neatle stands out more on the shelves. The color pops more.
# 1            It opened smoothly along the top. The Nestle did not open along the top se bit ripped some.
# 2                      It was easy to open and measured out where they could be put onto a cookie sheet.
# 3                                                                 Pillsbury was a little easier to open.
# 4    The cookies were individually portioned. With the nestle cookie I cut the individual portions fr...
# ..                                                                                                   ...
# 222                                                                                       Easier to open
# 223         It was a little bigger, so it had more room for the cookie dough. It was easier to cut open.
# 224                                                                Its easier to cut in a straight line
# 225  Nestle tollhouse packaging opened along the seam in the back but pillsbury ripped and it messed ...
# 226                                                  Its was blue and white and much easier to too open
#
# [227 rows x 4 columns]
